# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Madhu\naresh it\EDA\bank - bank.csv")
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
cat_columns=df.select_dtypes(include="object").columns
print(cat_columns)
num_columns=df.select_dtypes(exclude="object").columns
(num_columns)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
import os
os.getcwd()

try:
    root_directory=os.getcwd()
    new_folder="bank_graphs_seaborn"
    new_dir=os.path.join(root_directory,new_folder)
    os.makedirs(new_dir)

except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Madhu\\naresh it\\EDA\\bank_graphs_seaborn'

# %%
for i in cat_columns[1:]:
    plt.figure(figsize=(8,5))
    order_continent=df[i].value_counts().keys()
    sns.countplot(data=df,
                  x=i,
                  order=order_continent)
    plt.title("bar chart")
    plt.savefig(f"{new_dir}\{i} bank_graphs_seaborn.jpg")
    plt.show()

# %%
sns.countplot(data=df,x="marital")
plt.title("bar chart")
plt.savefig(f"{new_dir}\{i}bank_graphs_seaborn.jpg")
plt.show()

# %%
cat_columns=df.select_dtypes(include="object").columns
print(cat_columns)
num_columns=df.select_dtypes(exclude="object").columns
(num_columns)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
marital_status=df["marital"].unique()
count=[]
for i in df["marital"].unique():
    con=df["marital"]==i
    count.append(len(df[con]))
col=["marital_status","number of people"]
marital_status_df=pd.DataFrame(zip(marital_status,count),columns=col)
marital_status_df
# Out:
#   marital_status  number of people
# 0        married              2797
# 1         single              1196
# 2       divorced               528

# %%
import os
os.getcwd()

try:
    root_directory=os.getcwd()
    new_folder="bank_graphs_matplotlib"
    new_dir=os.path.join(root_directory,new_folder)
    os.makedirs(new_dir)

except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Madhu\\naresh it\\EDA\\bank_graphs_matplotlib'

# %%
plt.bar("marital_status","number of people",data=marital_status_df)
plt.savefig(f"{new_dir}\{i}bank_graphs_matplotlib.jpg")
plt.show()

# %%
cols=cat_columns[:]
cols
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')
