# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"J:\Downloads\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df["continent"].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
case_status=visa_df["case_status"].unique()
count=[]
for i in visa_df["case_status"].unique():
    con=visa_df["case_status"]==i
    count.append(len(visa_df[con]))
col=["case status","number of applicants"]
case_status_df=pd.DataFrame(zip(case_status,count),columns=col)
case_status_df
# Out:
#   case status  number of applicants
# 0      Denied                  8462
# 1   Certified                 17018

# %%
plt.bar("case status","number of applicants",data=case_status_df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
case_status=visa_df["case_status"].unique()
count=[]
for i in visa_df["case_status"].unique():
    con=visa_df["case_status"]==i
    count.append(len(visa_df[con]))
col=["case status","number of applicants"]
case_status_df=pd.DataFrame(zip(case_status,count),columns=col)
case_status_df.to_csv("case_status_df.csv",index=False)
case_status_df
# Out:
#   case status  number of applicants
# 0      Denied                  8462
# 1   Certified                 17018

# %% [markdown]
# **Bar chart using seaborn**

# %% [markdown]
# - we can plot bar chart using many packages
# - one package is matplotlib
# - another one is seaborn
# - in matplotlib the method is **plt.bar plot**
# - in seaborn the method is **countplot**
#
# - in matplotlib
#   - we take the row data
#   - we will create frequency table i.e DataFrame
#   - we will pass the columns1, columns2, and DataFarme
#
# - in seaborn
#   - it takes direct raw data
#   - we will provide direct columns name
#   - we will provide main dataframe

# %%
#continent colums ===== continent_df=======plt.bar
# continent column directly======visa_df


import seaborn as sns
sns.countplot(data=visa_df,x="continent")
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
order_continent=['Asia','Europe','North America','South America','Africa','Oceania']
sns.countplot(data=visa_df,x="continent",order=order_continent)
plt.title("bar chart")
plt.savefig("continents_bar_chart_using_seaborn.jpg")
plt.show()

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
plt.figure(figsize=(10,5))
order_continent=visa_df['continent'].value_counts().keys()
sns.countplot(data=visa_df,x="continent",order=order_continent)
plt.title("bar chart")
plt.savefig("continents_bar_chart_using_seaborn.jpg")
plt.show()

# %% [markdown]
# **Task-3**
# **Bar Charts using for loop**

# %% [markdown]
# **using for loop plot the bar charts of all the catsgerical columns**
# - we can use seaborn and matplotlib
# - seaborn:countplot requires only raw data, directly column name and main data
# - matplotlib:requires frequency table
#    - from row data,will make value counts
#    - from value counts we are making keys and value seperatly
#    - then we are creating dataframe
#
# -

# %%
cat_columns=visa_df.select_dtypes(include="object").columns
num_columns=visa_df.select_dtypes(exclude="object").columns

# %%
import os
try:
    root_directory=os.getcwd()
    new_folder="graphs_seaborn"
    new_dir=os.path.join(root_directory,new_folder)
    os.makedirs(new_dir)

except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Madhu\\naresh it\\EDA\\graphs_seaborn'

# %%
import seaborn as sns

for i in cat_columns[1:]:
    plt.figure(figsize=(8,5))
    order_continent=visa_df[i].value_counts().keys()
    sns.countplot(data=visa_df,
                  x=i,
                  order=order_continent)
    plt.title("bar chart")
    plt.savefig(f"{new_dir}\{i}_seaborn.jpg")
    plt.show()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Madhu\\naresh it\\EDA'

# %% [markdown]
# **os.makedirs()**
#
# - makedir creates a leaf directory
# - means it will take the current working directory and create one extra folder
# - here my python file in **EDA** folder
# - now i want to create new folder **graphs_seaborn**
# - which is one step ahead of EDA folder : EDA/graphs_seaborn
# - pass the full path in the makedir()
# - 'C:\\Users\\Madhu\\naresh it\\EDA'

# %%
os.makedirs('C:\\Users\\Madhu\\naresh it\\EDA\\graphs_seaborn')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 os.makedirs('C:\\Users\\Madhu\\naresh it\\EDA\\graphs_seaborn')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Madhu\\naresh it\\EDA\\graphs_seaborn'

# %%
#step-1:
root_directory=os.getcwd()
root_directory

#step-2:
new_folder="graphs_seaborn"

#step-3:
new_dir=os.path.join(root_directory,new_folder)
new_dir

#step-4:
os.makedirs(new_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[17], line 13
#      10 new_dir
#      12 #step-4:
# ---> 13 os.makedirs(new_dir)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Madhu\\naresh it\\EDA\\graphs_seaborn'

# %%
new_dir

# %%
try:
    root_directory=os.getcwd()
    new_folder="graphs_matplotlib"
    new_dir=os.path.join(root_directory,new_folder)
    os.makedirs(new_dir)

except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Madhu\\naresh it\\EDA\\graphs_matplotlib'

# %%
case_status=visa_df["case_status"].unique()
count=[]
for i in visa_df["case_status"].unique():
    con=visa_df["case_status"]==i
    count.append(len(visa_df[con]))
col=["case status","number of applicants"]
case_status_df=pd.DataFrame(zip(case_status,count),columns=col)
case_status_df
# Out:
#   case status  number of applicants
# 0      Denied                  8462
# 1   Certified                 17018

# %%
plt.figure(figsize=(10,5))
order_continent=visa_df['continent'].value_counts().keys()
sns.countplot(data=visa_df,
              x="continent",
              order=order_continent,
              width=0.5)
plt.title("bar chart")
plt.savefig("continents_bar_chart_using_seaborn.jpg")
plt.show()

# %% [markdown]
# **sub-plots**
# - if we have multiple plots when we apply for loop it is giving one by one
# - it is hard to see the graphs
# - sub-plots its a kind of a matrix representation
# - suppose we have a 2/2 matrix means 4 values, means we can plot 4 plots
# - first plot possition represents with : 2,2,1
# - second plot possition represents with : 2,2,2
# - third plot possition represents with : 2,2,3
# - fourth plot possition represents with : 2,2,4

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,1,1)
# Out:
# <Axes: >

# %%
plt.subplot(2,1,2)
# Out:
# <Axes: >

# %%
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
for i in range(1,3):
    plt.subplot(1,2,i)

# %%
for i in range(1,3):
    plt.subplot(2,1,i)

# %%
for i in range(1,3):
    plt.subplot(1,2,i)

# %%
#  TASK-1
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
sns.countplot(x="continent",data=visa_df)
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
sns.countplot(x="case_status",data=visa_df)
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %%
plt.subplot(1,2,1)
sns.countplot(x="continent",data=visa_df)
plt.subplot(1,2,2)
sns.countplot(x="case_status",data=visa_df)
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %%
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
sns.countplot(x="continent",data=visa_df)
plt.subplot(1,2,2)
sns.countplot(x="case_status",data=visa_df)
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %% [markdown]
# #TASK-2
#
# - plot the four plots
# - continents
# - has_job_experiance
# - requires_job_experiance
# - case_ststus
# -

# %%
sns.countplot(x="continent",data=visa_df)
sns.countplot(x="has_job_experience",data=visa_df)
sns.countplot(x="requires_job_training",data=visa_df)
sns.countplot(x="case_status",data=visa_df)
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %%
plt.figure(figsize=(23,15))
plt.subplot(2,2,1)
sns.countplot(x="continent",data=visa_df)
plt.title("continent")
#============================================================================
plt.subplot(2,2,2)
sns.countplot(x="has_job_experience",data=visa_df)
plt.title("has_job_experience")
#================================================================================
plt.subplot(2,2,3)
sns.countplot(x="requires_job_training",data=visa_df)
plt.title("requires_job_training")
#=================================================================================
plt.subplot(2,2,4)
sns.countplot(x="case_status",data=visa_df)
plt.title("case_status")
# Out:
# Text(0.5, 1.0, 'case_status')

# %%
cols=cat_columns[1:]
plt.figure(figsize=(16,18))
for i in range(len(cols)):
    plt.subplot(3,3,i+1)
    sns.countplot(x=cols[i],data=visa_df)

# %% [markdown]
# # Method-3

# %% [markdown]
# - import the packages
# - read the data
# - make categorical and numerical data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
types=visa_df.dtypes
cat_col=[key for key , value in types.items() if value=="object"]
num_col=[key for key, value in types.items() if value!="object"]

# %%
cds=visa_df["continent"].value_counts()
cds
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
ax=cds.plot(kind="bar")
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # PIE CHART

# %% [markdown]
# - pie chart is a 360 degree view
# - it is under matplotlib package
# - it will takes keys and values
# - that we will get from value counts

# %%
# step-1: get keys from continent value counts 
# step-2: get values from continent value counts
# step-3: plt.pie verify the argument
#            which argument takes values and keys

# %%
keys=visa_df["continent"].value_counts().keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
vals=visa_df["continent"].value_counts().values
vals
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
keys=visa_df["continent"].value_counts().keys()
vals=visa_df["continent"].value_counts().values
plt.pie(x=vals,                              # values
        explode=[0.5,0.5,0.5,0.5,0.5,0.5],   # divides the pie
        labels=keys,                         # keys
        radius=2,                            # sixe of pie
        startangle=45,                       # angle to rotate
        autopct="%0.2f%%")                   #getting the percentage on pie
plt.show()
